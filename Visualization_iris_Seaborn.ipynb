# %%
import os
os.chdir('/home/janaki/Pandas')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
iris = pd.read_csv('Iris_data_sample.csv',index_col=0,na_values=['###','??'])

# %%
iris.dropna(axis=0,inplace=True)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  146 non-null    object
#  1   SepalWidthCm   146 non-null    float64
#  2   PetalLengthCm  146 non-null    float64
#  3   PetalWidthCm   146 non-null    float64
#  4   Species        146 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 6.8+ KB

# %%
iris.replace('five',5,inplace=True)
iris['SepalLengthCm'] = iris['SepalLengthCm'].astype(float)

# %%
g1 = iris.groupby('Species')

# %%
for SepalLengthCm,SepalWidthCm in g1:
    print(SepalLengthCm,SepalWidthCm)
# Out:
# Iris-setosa     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa
# 11            5.4           3.7            1.5           0.2  Iris-setosa
# 12            4.8           3.4            1.6           0.2  Iris-setosa
# 13            4.8           3.0            1.4           0.1  Iris-setosa
# 14            4.3           3.0            1.1           0.1  Iris-setosa
# 15            5.8           4.0            1.2           0.2  Iris-setosa
# 16            5.7           4.4            1.5           0.4  Iris-setosa
# ...

# %%
g1.first()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa                5.1           3.5            1.4           0.2
# Iris-versicolor            7.0           3.2            4.7           1.4
# Iris-virginica             6.3           3.3            6.0           2.5

# %%
g1.size()
# Out:
# Species
# Iris-setosa        46
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
g1.aggregate('mean')
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa           5.008696      3.419565        1.46087      0.243478
# Iris-versicolor       5.936000      2.770000        4.26000      1.326000
# Iris-virginica        6.588000      2.974000        5.55200      2.026000

# %%
iris.set_index('Species',inplace=True)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, Iris-setosa to Iris-virginica
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  146 non-null    float64
#  1   SepalWidthCm   146 non-null    float64
#  2   PetalLengthCm  146 non-null    float64
#  3   PetalWidthCm   146 non-null    float64
# dtypes: float64(4)
# memory usage: 5.7+ KB

# %%
sns.set(style='darkgrid')
sns.regplot(x=iris['SepalLengthCm'],y = iris['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.set(style='darkgrid')
sns.regplot(x=iris['SepalLengthCm'],y = iris['PetalLengthCm'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.set(style='darkgrid')
sns.regplot(x=iris['SepalLengthCm'],y = iris['PetalLengthCm'],fit_reg=False,marker='*')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.lmplot(x='SepalLengthCm',y = 'PetalLengthCm',data=iris,fit_reg=False,hue='Species',legend=True,palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8e48bfa559ea> in <module>
# ----> 1 sns.lmplot(x='SepalLengthCm',y = 'PetalLengthCm',data=iris,fit_reg=False,hue='Species',legend=True,palette='Set1')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.histplot(iris['SepalWidthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(iris['SepalWidthCm'],bins=5)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
iris.insert(2,'SWidth_quarter','')

# %%
for i in range(0,len(iris)):
    print(iris.iat[i,1])
    if iris.iat[i,1]<=2.8:
        iris.iat[i,2] =1
    elif iris.iat[i,1]<=3.0:
        iris.iat[i,2] =2
    elif iris.iat[i,1]<=3.3:
        iris.iat[i,2] =3
    else:        
        iris.iat[i,2] =4
# Out:
# 3.5
# 3.2
# 3.4
# 3.4
# 2.9
# 3.1
# 3.7
# 3.4
# 3.0
# 3.0
# 4.0
# 4.4
# 3.9
# 3.5
# 3.8
# 3.8
# 3.4
# 3.7
# 3.6
# 3.3
# 3.4
# 3.0
# 3.4
# 3.5
# 3.4
# 3.2
# 3.1
# 3.4
# 4.1
# 4.2
# 3.1
# 3.2
# 3.5
# 3.1
# 3.0
# 3.4
# 3.5
# 2.3
# 3.2
# 3.5
# 3.8
# 3.0
# 3.8
# 3.2
# 3.7
# 3.3
# 3.2
# 3.2
# 3.1
# 2.3
# 2.8
# 2.8
# 3.3
# 2.4
# 2.9
# 2.7
# 2.0
# 3.0
# 2.2
# 2.9
# 2.9
# 3.1
# 3.0
# 2.7
# 2.2
# 2.5
# 3.2
# 2.8
# 2.5
# 2.8
# 2.9
# 3.0
# 2.8
# 3.0
# 2.9
# 2.6
# 2.4
# 2.4
# 2.7
# 2.7
# 3.0
# 3.4
# 3.1
# 2.3
# 3.0
# 2.5
# 2.6
# 3.0
# 2.6
# 2.3
# 2.7
# 3.0
# 2.9
# 2.9
# 2.5
# 2.8
# 3.3
# 2.7
# 3.0
# 2.9
# 3.0
# 3.0
# 2.5
# 2.9
# 2.5
# 3.6
# 3.2
# 2.7
# 3.0
# 2.5
# 2.8
# 3.2
# 3.0
# 3.8
# 2.6
# 2.2
# 3.2
# 2.8
# 2.8
# 2.7
# 3.3
# 3.2
# 2.8
# 3.0
# 2.8
# 3.0
# 2.8
# 3.8
# 2.8
# 2.8
# 2.6
# 3.0
# 3.4
# 3.1
# 3.0
# 3.1
# 3.1
# 3.1
# 2.7
# 3.2
# 3.3
# 3.0
# 2.5
# 3.0
# 3.4
# 3.0

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, Iris-setosa to Iris-virginica
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SepalLengthCm   146 non-null    float64
#  1   SepalWidthCm    146 non-null    float64
#  2   SWidth_quarter  146 non-null    object
#  3   PetalLengthCm   146 non-null    float64
#  4   PetalWidthCm    146 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 6.8+ KB

# %%
iris['Species'] = iris['Species'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-cd753b52e93f> in <module>
# ...

# %%
iris['SWidth_quarter'] = iris['SWidth_quarter'].astype('category')

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
sns.distplot(iris.SepalWidthCm,bins=15)
# Out:
# /home/janaki/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, Iris-setosa to Iris-virginica
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SepalLengthCm   146 non-null    float64
#  1   SepalWidthCm    146 non-null    float64
#  2   SWidth_quarter  146 non-null    category
#  3   PetalLengthCm   146 non-null    float64
#  4   PetalWidthCm    146 non-null    float64
# dtypes: category(1), float64(4)
# memory usage: 6.0+ KB

# %%
sns.countplot(x='Species',data=iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-77e0869ef098> in <module>
# ----> 1 sns.countplot(x='Species',data=iris)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# -> 3595     plotter = _CountPlotter(
#    3596         x, y, hue, data, order, hue_order,
#    3597         estimator, ci, n_boot, units, seed,
#
# ...

# %%
sns.countplot(x='Species',data=iris,hue='SWidth_quarter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-6c84f6bc2ed0> in <module>
# ----> 1 sns.countplot(x='Species',data=iris,hue='SWidth_quarter')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# -> 3595     plotter = _CountPlotter(
#    3596         x, y, hue, data, order, hue_order,
#    3597         estimator, ci, n_boot, units, seed,
#
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  149 non-null    object
#  1   SepalWidthCm   149 non-null    float64
#  2   PetalLengthCm  148 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        149 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 7.0+ KB

# %%
sns.boxplot(x = iris["SepalLengthCm"],orient='h',palette='viridis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f3d4d4ace036> in <module>
# ----> 1 sns.boxplot(x = iris["SepalLengthCm"],orient='h',palette='viridis')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
# ...

# %%
sns.boxplot(y=iris['Species'],x = iris["PetalLengthCm"],orient='h')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x='PetalLengthCm',y = "Species",hue='SWidth_quarter',data=iris,orient='h')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a92d73bc098b> in <module>
# ----> 1 sns.boxplot(x='PetalLengthCm',y = "Species",hue='SWidth_quarter',data=iris,orient='h')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
# ...

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
sns.boxplot(data=iris,orient='h',palette='viridis')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(iris.corr('pearson'),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(iris,kind='scatter',hue='Species')
plt.show()
